# %%
import pandas as pd
import requests

# %%
entrepreneurs = pd.read_excel('project/data/реестр_предпринимателей.xlsx', sheet_name='Лист1', skiprows=2)
entrepreneurs.head()
# Out:
# /home/yn/Documents/Python/test/.venv/lib/python3.13/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    № п/п                                 Наименование / ФИО      Тип субъекта  \
# 0      1  " МЕГАПОЛИС " ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВ...  Юридическое лицо
# 1      2  " СТАЛЬИНВЕСТСТРОЙ " ОБЩЕСТВО С ОГРАНИЧЕННОЙ О...  Юридическое лицо
# 2      3  " СТРОЙТЕХНИКА - М " ОБЩЕСТВО С ОГРАНИЧЕННОЙ О...  Юридическое лицо
# 3      4   "БАЗИС" ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ  Юридическое лицо
# 4      5   "БЕЛАГ" ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ  Юридическое лицо
#
#                    Категория           ОГРН         ИНН  \
# 0  Не является субъектом МСП  1027800523376  7801190028
# 1  Не является субъектом МСП  1037800033545  7801227976
# 2  Не является субъектом МСП  1025204418293  5263039399
# 3           Микропредприятие  1025204411682  5263025484
# 4  Не является субъектом МСП  1037800039276  7801123215
#
#                     Основной вид деятельности                      Регион  \
# 0   41.2 Строительство жилых и нежилых зданий      78 - г.Санкт-Петербург
# 1  41.20 Строительство жилых и нежилых зданий      78 - г.Санкт-Петербург
# 2  41.20 Строительство жилых и нежилых зданий  52 - Нижегородская область
# 3  41.20 Строительство жилых и нежилых зданий  52 - Нижегородская область
# 4  41.20 Строительство жилых и нежилых зданий      78 - г.Санкт-Петербург
#
#   Район              Город  ... Дата исключения из реестра Телефон E-mail  \
# 0   NaN                NaN  ...                 10.10.2021     NaN    NaN
# 1   NaN                NaN  ...                 10.08.2018     NaN    NaN
# 2   NaN  г Нижний Новгород  ...                 10.07.2022     NaN    NaN
# 3   NaN  г Нижний Новгород  ...                        NaN     NaN    NaN
# 4   NaN                NaN  ...                 10.07.2021     NaN    NaN
#
#    WWW Наличие лицензий Наличие заключенных договоров, контрактов  \
# 0  NaN              Нет                                       Нет
# 1  NaN              Нет                                       Нет
# 2  NaN              Нет                                       Нет
# 3  NaN              Нет                                       Нет
# 4  NaN              Нет                                       Нет
#
#   Производство инновационной, высокотехнологичной продукции  \
# 0                                                Нет
# 1                                                Нет
# 2                                                Нет
# 3                                                Нет
# 4                                                Нет
#
#   Участие в программах партнерства Является социальным предприятием  \
# 0                              Нет                              Нет
# 1                              Нет                              Нет
# 2                              Нет                              Нет
# 3                              Нет                              Нет
# 4                              Нет                              Нет
#
#   Среднесписочная численность работников за предшествующий календарный год
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                1.0
# 4                                                NaN
#
# [5 rows x 23 columns]

# %%
entrepreneurs.drop("№ п/п", axis=1, inplace=True)

# %%
type_mask = (
    (entrepreneurs['Тип субъекта'] == 'Юридическое лицо') & 
    (entrepreneurs['Категория'].isin(['Малое предприятие', 'Среднее предприятие'])) &
    (entrepreneurs['Основной вид деятельности'] == '41.20 Строительство жилых и нежилых зданий')
)

entrepreneurs = entrepreneurs[type_mask]
entrepreneurs
# Out:
#                                        Наименование / ФИО      Тип субъекта  \
# 19      "КОРПОРАЦИЯ ВИТ" (ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВ�
# 580132             20 - Чеченская Республика  Ачхой-Мартановский р-н
# 580134  07 - Кабардино-Балкарская Республика            Зольский р-н
#
#                 Город Населенный пункт  ... Дата исключения из реестра  \
# 19                NaN              NaN  ...                        NaN
# 51      г Дзержинский              NaN  ...                        NaN
# 4652              NaN              NaN  ...                        NaN
# 4667       г Владимир              NaN  ...                        NaN
# 4673              NaN              NaN  ...                        NaN
# ...               ...              ...  ...                        ...
# 560511        г Анапа              NaN  ...                        NaN
# 560512        г Анапа              NaN  ...                        NaN
# 560902     г Корсаков              NaN  ...                        NaN
# 580132            NaN        с Валерик  ...                        NaN
# 580134            NaN          с Малка  ...                        NaN
#
#        Телефон E-mail  WWW Наличие лицензий  \
# 19         NaN    NaN  NaN              Нет
# 51         NaN    NaN  NaN               Да
# 4652       NaN    NaN  NaN               Да
# 4667       NaN    NaN  NaN               Да
# 4673       NaN    NaN  NaN               Да
# ...        ...    ...  ...              ...
# 560511     NaN    NaN  NaN              Нет
# 560512     NaN    NaN  NaN              Нет
# 560902     NaN    NaN  NaN               Да
# 580132     NaN    NaN  NaN               Да
# 580134     NaN    NaN  NaN              Нет
#
#        Наличие заключенных договоров, контрактов  \
# 19                                           Нет
# 51                                           Нет
# 4652                                         Нет
# 4667                                         Нет
# 4673                                         Нет
# ...                                          ...
# 560511                                       Нет
# 560512                                       Нет
# 560902                                       Нет
# 580132                                       Нет
# 580134                                       Нет
#
#        Производство инновационной, высокотехнологичной продукции  \
# 19                                                    Нет
# 51                                                    Нет
# 4652                                                  Нет
# 4667                                                  Нет
# 4673                                                  Нет
# ...                                                   ...
# 560511                                                Нет
# 560512                                                Нет
# 560902                                                Нет
# 580132                                                Нет
# 580134                                                Нет
#
#        Участие в программах партнерства Является социальным предприятием  \
# 19                                  Нет                              Нет
# 51                                  Нет                              Нет
# 4652                                Нет                              Нет
# 4667                                Нет                              Нет
# 4673                                Нет                              Нет
# ...                                 ...                              ...
# 560511                              Нет                              Нет
# 560512                              Нет                              Нет
# 560902                              Нет                              Нет
# 580132                              Нет                              Нет
# 580134                              Нет                              Нет
#
#        Среднесписочная численность работников за предшествующий календарный год
# 19                                                   36.0
# 51                                                  201.0
# 4652                                                 35.0
# 4667                                                 52.0
# 4673                                                 21.0
# ...                                                   ...
# 560511                                                4.0
# 560512                                               74.0
# 560902                                              145.0
# 580132                                               67.0
# 580134                                               11.0
#
# [8927 rows x 22 columns]

# %%
session = requests.Session()
session.headers.update({
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
        'Accept': 'application/json, text/plain, */*',
        'Referer': 'https://bo.nalog.ru/'
    })
a = 5038038838
# res = session.get(f"https://bo.nalog.ru/advanced-search/organizations/search?query={a}&page=0").json()

# org_id = res["content"][0]["id"]

session.get(f'https://bo.nalog.gov.ru/search?query={a}')
# Out:
# <Response [403]>
